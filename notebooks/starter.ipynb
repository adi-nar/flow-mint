# %%
import os
import sys

proot = os.path.abspath(os.path.join(os.getcwd(), '..'))
if proot not in sys.path:
    sys.path.append(proot)
import flow_mint
from flow_mint.parser.hdfc import HDFCParser
from flow_mint.utils.config import ConfigRegistry
if os.path.exists(ppath := os.path.join(proot, 'flow_mint/config.yaml')):
    cfg_path = os.path.join(proot, 'flow_mint/config.yaml')

print(cfg_path)
# Out:
# /Users/aditya/yard/vault/aditya/core_stuff/builds/flow_mint/flow_mint/config.yaml

# %%
config = ConfigRegistry(cfg_path)
hdfc = HDFCParser()

# %%
# print(hdfc.parse(os.path.join(config.get_bank_paths('HDFC'), 'hdfc-account-statement_29aug25_to_30sept25.xls'), config.get_bank_ftype('HDFC')))

# %%
import polars as pl
raw_df = pl.read_excel(os.path.join(config.get_bank_paths('HDFC'), 'hdfc-account-statement_29aug25_to_30sept25.xls'), has_header=False)

# %%
raw_df
# Out:
# shape: (67, 7)
# ┌──────────────────┬─────────────────┬──────────┬──────────┬─────────────────┬──────────┬──────────┐
# │ column_1         ┆ column_2        ┆ column_3 ┆ column_4 ┆ column_5        ┆ column_6 ┆ column_7 │
# │ ---              ┆ ---             ┆ ---      ┆ ---      ┆ ---             ┆ ---      ┆ ---      │
# │ str              ┆ str             ┆ str      ┆ str      ┆ str             ┆ str      ┆ str      │
# ╞══════════════════╪═════════════════╪══════════╪══════════╪═════════════════╪══════════╪══════════╡
# │ HDFC BANK Ltd.   ┆ null            ┆ null     ┆ null     ┆ null            ┆ null     ┆ null     │
# │ …                ┆                 ┆          ┆          ┆                 ┆          ┆          │
# │ null             ┆ null            ┆ null     ┆ null     ┆ Account Branch  ┆ null     ┆ null     │
# │                  ┆                 ┆          ┆          ┆ :BANNERJI ROAD  ┆          ┆          │
# ...

# %%
# !pip install anndata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 21.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [anndata]m6/9 [array-api-compat]
# ...

# %%
# import anndata as ad
# data = ad.read_h5ad("/Users/aditya/Downloads/vcc_data/adata_Training.h5ad")

# %%
data.write_zarr("/Users/aditya/Downloads/vcc_data/t_adata.zarr", chunks=(5000, 1000))
